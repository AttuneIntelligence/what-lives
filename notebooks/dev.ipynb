# %%
import json, re, os
import pandas as pd
import numpy as np
import asyncio
import nest_asyncio
from tqdm.notebook import tqdm
nest_asyncio.apply()

from src import *

# %%
inference = Inference()
whatlives = WhatLives(
    inference=inference,
    model="GPT-4o", 
    n_max=16
)
# Out:
# Authenciated to API clients in 0.21 seconds.
# Initialized model for analysis: GPT-4o

# %%
whatlives.analyze_definitions()
# Out:
# Computing correlation matrices...
#   0%|          | 0/256 [00:00<?, ?it/s]
# --- COMPLETE ---
# total cost: $3.07
# Elbow Clusters: 14
# /workspace/what-lives/src/what_lives.py:414: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.95, 0.95])
# CLUSTER STATISTICS
# ...
#
# Total number of clusters: 14
# Average cluster size: 1.1 definitions
#
# Cluster sizes:
# Cluster 1: 2 definitions (12.5%)
# Cluster 2: 1 definitions (6.2%)
# Cluster 3: 1 definitions (6.2%)
# Cluster 4: 1 definitions (6.2%)
# Cluster 5: 2 definitions (12.5%)
# Cluster 6: 1 definitions (6.2%)
# Cluster 7: 1 definitions (6.2%)
# Cluster 8: 1 definitions (6.2%)
# Cluster 9: 1 definitions (6.2%)
# Cluster 10: 1 definitions (6.2%)
# Cluster 11: 1 definitions (6.2%)
# Cluster 12: 1 definitions (6.2%)
# Cluster 13: 1 definitions (6.2%)
# Cluster 14: 1 definitions (6.2%)
#
# CLUSTER ANALYSIS OF LIFE DEFINITIONS
# ...
#
#
# Cluster 1
# ...
