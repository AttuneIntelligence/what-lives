# %%
import json, re, os
import pandas as pd
import numpy as np
import asyncio
import nest_asyncio
from tqdm.notebook import tqdm
nest_asyncio.apply()

from src import *

# %%
inference = Inference()
whatlives = WhatLives(
    inference=inference,
    model="GPT-4o", 
    n_max=16,
    semaphore_limit=66,
    n_replicates=3
)
# Out:
# Authenciated to API clients in 0.23 seconds.
# Initialized model for analysis: GPT-4o

# %%
whatlives.analyze_definitions()
# inference.test_acomplete()
# Out:
# Computing 256 remaining correlation pairs...
#   0%|          | 0/256 [00:00<?, ?it/s]
# Saving checkpoint 1...
# Checkpoint saved. Completed 10/256 pairs.
#
# Saving checkpoint 2...
# Checkpoint saved. Completed 20/256 pairs.
#
# Saving checkpoint 3...
# Checkpoint saved. Completed 30/256 pairs.
#
# Saving checkpoint 4...
# Checkpoint saved. Completed 40/256 pairs.
#
# Saving checkpoint 5...
# Checkpoint saved. Completed 50/256 pairs.
#
# Saving checkpoint 6...
# Checkpoint saved. Completed 60/256 pairs.
#
# Saving checkpoint 7...
# Checkpoint saved. Completed 70/256 pairs.
#
# Saving checkpoint 8...
# Checkpoint saved. Completed 80/256 pairs.
#
# Saving checkpoint 9...
# Checkpoint saved. Completed 90/256 pairs.
#
# Saving checkpoint 10...
# Checkpoint saved. Completed 100/256 pairs.
#
# Saving checkpoint 11...
# Checkpoint saved. Completed 110/256 pairs.
#
# Saving checkpoint 12...
# Checkpoint saved. Completed 120/256 pairs.
#
# Saving checkpoint 13...
# ...
